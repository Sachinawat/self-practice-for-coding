# %%
import pandas as pd
import numpy as np
file_path = r"C:\Users\Sachin Awati\SACHIN'S WORKSPACE\Testing\self-practice-for-coding\Folder\stock\tcs_data_pipeline\output\TCS_10Y_ALL_DATA.csv"

df = pd.read_csv(file_path)

print(df.head())
print(df.info())
# Out:
#    Year         Open         High          Low        Close        Volume  \
# 0  2015   969.866426   990.863450   936.306776   973.594933  1.773608e+06
# 1  2016   981.511356  1119.737486   839.316124   981.618492  2.191959e+06
# 2  2017  1023.589241  1158.446527   883.182339  1023.779928  2.210239e+06
# 3  2018  1502.870675  1922.790354  1092.878968  1502.901093  3.452862e+06
# 4  2019  1803.542699  2002.902668  1530.669598  1801.708357  3.026918e+06
#
#     Returns       DMA_50      DMA_200  Volatility_30D  Revenue  Net_Income  \
# 0  0.002080          NaN          NaN             NaN      NaN         NaN
# 1  0.000057   991.222289   994.124775        0.014557      NaN         NaN
# 2  0.000695  1006.087802   990.947361        0.012393      NaN         NaN
# 3  0.001565  1449.263450  1268.033656        0.015788      NaN         NaN
# 4  0.000793  1778.568670  1715.372250        0.014338      NaN         NaN
#
#    EPS  Equity  PE  ROE  ROCE
# 0  NaN     NaN NaN  NaN   NaN
# ...

# %%
df
# Out:
#     Year         Open         High          Low        Close        Volume  \
# 0   2015   969.866426   990.863450   936.306776   973.594933  1.773608e+06
# 1   2016   981.511356  1119.737486   839.316124   981.618492  2.191959e+06
# 2   2017  1023.589241  1158.446527   883.182339  1023.779928  2.210239e+06
# 3   2018  1502.870675  1922.790354  1092.878968  1502.901093  3.452862e+06
# 4   2019  1803.542699  2002.902668  1530.669598  1801.708357  3.026918e+06
# 5   2020  2008.929066  2637.191071  1323.145273  2008.089398  3.982160e+06
# 6   2021  3016.933152  3596.490725  2571.976504  3015.770794  2.753121e+06
# 7   2022  3093.090530  3651.347804  2672.154542  3090.618323  2.344873e+06
# 8   2023  3189.956391  3725.685658  2874.947082  3190.786133  1.933396e+06
# 9   2024  3930.701208  4427.081095  3454.301549  3930.607141  2.413507e+06
# 10  2025  3360.305333  4177.633455  2855.948356  3356.944018  2.694074e+06
#
# ...
